# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('BigBasket Products.csv')
df = df.drop(columns = 'index')
df.head()
# Out:
#                                              product                category  \
# 0             Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1                              Water Bottle - Orange  Kitchen, Garden & Pets
# 2                     Brass Angle Deep - Plain, No.2    Cleaning & Household
# 3  Cereal Flip Lid Container/Storage Jar - Assort...    Cleaning & Household
# 4                 Creme Soft Soap - For Hands & Body        Beauty & Hygiene
#
#             sub_category              brand  sale_price  market_price  \
# 0              Hair Care  Sri Sri Ayurveda        220.0         220.0
# 1  Storage & Accessories         Mastercook       180.0         180.0
# 2            Pooja Needs                Trm       119.0         250.0
# 3   Bins & Bathroom Ware             Nakoda       149.0         176.0
# 4       Bath & Hand Wash              Nivea       162.0         162.0
#
#                        type  rating  \
# 0          Hair Oil & Serum     4.1
# ...

# %%
df.tail()
# Getting last 5 rows
# Out:
#                                           product              category  \
# 27550  Wottagirl! Perfume Spray - Heaven, Classic      Beauty & Hygiene
# 27551                                    Rosemary  Gourmet & World Food
# 27552                Peri-Peri Sweet Potato Chips  Gourmet & World Food
# 27553                   Green Tea - Pure Original             Beverages
# 27554              United Dreams Go Far Deodorant      Beauty & Hygiene
#
#                    sub_category                       brand  sale_price  \
# 27550         Fragrances & Deos                      Layerr      199.20
# 27551    Cooking & Baking Needs                    Puramate       67.50
# 27552  Snacks, Dry Fruits, Nuts                      FabBox      200.00
# 27553                       Tea                      Tetley      396.00
# 27554            Men's Grooming  United Colors Of Benetton       214.53
#
#        market_price                      type  rating  \
# ...

# %%
df.sample(5)
# Getting random 5 rows
# Out:
#                              product              category  \
# 20440                      Raw Mango   Fruits & Vegetables
# 4851   Nescafe - Cap Colombie Coffee  Gourmet & World Food
# 329          Tea - English Breakfast             Beverages
# 7966                 Detox Green Tea             Beverages
# 481              Olive Oil - Classic  Gourmet & World Food
#
#              sub_category        brand  sale_price  market_price  \
# 20440        Fresh Fruits       Fresho        16.0          22.5
# 4851   Drinks & Beverages     Nescafe        999.0         999.0
# 329                   Tea       Typhoo       166.0         195.0
# 7966                  Tea       FabBox       280.0         280.0
# 481        Oils & Vinegar  La Espanola       589.0        1350.0
#
#                          type  rating  \
# 20440         Seasonal Fruits     NaN
# 4851         Coffee & Pre-Mix     NaN
# 329                  Tea Bags     4.5
# 7966          Leaf & Dust Tea     5.0
# ...

# %%
df.shape
# Our dataset has 27555 rows and 9 columns
# Out:
# (27555, 9)

# %%
df.info()
# Getting information about columns and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product       27554 non-null  object
#  1   category      27555 non-null  object
#  2   sub_category  27555 non-null  object
#  3   brand         27554 non-null  object
#  4   sale_price    27555 non-null  float64
#  5   market_price  27555 non-null  float64
#  6   type          27555 non-null  object
#  7   rating        18929 non-null  float64
#  8   description   27440 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 1.9+ MB

# %%
df.isna().sum()
# Sum of null values each column has, rating has the most amount of null values
# Out:
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Drop Null values
# Out:
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# dtype: int64

# %%
df.shape
# Now we have 18840 rows and 9 columns
# Out:
# (18840, 9)

# %%
df.describe()
# Overall statistics about dataset
# Out:
#          sale_price  market_price        rating
# count  18840.000000  18840.000000  18840.000000
# mean     267.681222    322.011349      3.943063
# std      364.400131    459.124974      0.739646
# min        3.000000      3.000000      1.000000
# 25%       85.000000     95.000000      3.700000
# 50%      165.000000    195.000000      4.100000
# 75%      306.000000    370.000000      4.300000
# max     6660.000000   7400.000000      5.000000

# %% [markdown]
# # Univariate Analysis

# %%
df.head()
# Out:
#                                              product                category  \
# 0             Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1                              Water Bottle - Orange  Kitchen, Garden & Pets
# 2                     Brass Angle Deep - Plain, No.2    Cleaning & Household
# 3  Cereal Flip Lid Container/Storage Jar - Assort...    Cleaning & Household
# 4                 Creme Soft Soap - For Hands & Body        Beauty & Hygiene
#
#             sub_category              brand  sale_price  market_price  \
# 0              Hair Care  Sri Sri Ayurveda        220.0         220.0
# 1  Storage & Accessories         Mastercook       180.0         180.0
# 2            Pooja Needs                Trm       119.0         250.0
# 3   Bins & Bathroom Ware             Nakoda       149.0         176.0
# 4       Bath & Hand Wash              Nivea       162.0         162.0
#
#                        type  rating  \
# 0          Hair Oil & Serum     4.1
# ...

# %%
# Top 10 best sellers
df['product'].value_counts().head(10).plot(kind = 'pie', autopct = '%1.1f%%')
plt.show()

# %%
# Find the ditribution of sale_price

df['sale_price'].hist()
# We can see right skewed distribution, where most of the prices is between 0 and 1000
# Out:
# <Axes: >

# %%
df['sale_price'].skew()
# We got positive value which means it's right skewed disribution
# Out:
# 5.246416896493422

# %%
# What is the mean, median of the sale_price?

df['sale_price'].mean() #267.6812223991508
df['sale_price'].median() #165.0
# Out:
# 165.0

# %%
sns.boxplot(df['sale_price'], orient="h")
# As we can see we got a lot of outliers
# Out:
# <Axes: >

# %%
# Find percentage distribution of sale_price

np.quantile(df['sale_price'], [0.25, 0.5, 0.75, 1])
# 25% of the sale_price is less than 85; 50% of sale_price is below 165;
# 75% of the sale_price is less than 306; and 100% of the prices are less than 6660 (max)
# Out:
# array([  85.,  165.,  306., 6660.])

# %%
# Find 10 most popular brands

print(df['brand'].value_counts().head())
df['brand'].value_counts().head().plot(kind = 'bar')
# Out:
# bb Royal    278
# BB Home     172
# Amul        153
# Himalaya    139
# Cello       104
# Name: brand, dtype: int64
# <Axes: >

# %%
# Find distribution of ratings

df['rating'].hist()
# We can see that most of the rating are between 3.7 and 4.5, which is good
# Out:
# <Axes: >

# %% [markdown]
# # Bivariate Analysis

# %%
df.head()
# Out:
#                                              product                category  \
# 0             Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1                              Water Bottle - Orange  Kitchen, Garden & Pets
# 2                     Brass Angle Deep - Plain, No.2    Cleaning & Household
# 3  Cereal Flip Lid Container/Storage Jar - Assort...    Cleaning & Household
# 4                 Creme Soft Soap - For Hands & Body        Beauty & Hygiene
#
#             sub_category              brand  sale_price  market_price  \
# 0              Hair Care  Sri Sri Ayurveda        220.0         220.0
# 1  Storage & Accessories         Mastercook       180.0         180.0
# 2            Pooja Needs                Trm       119.0         250.0
# 3   Bins & Bathroom Ware             Nakoda       149.0         176.0
# 4       Bath & Hand Wash              Nivea       162.0         162.0
#
#                        type  rating  \
# 0          Hair Oil & Serum     4.1
# ...

# %%
# Scatter Plot, Correlation Coefficient,
# Categorical vs. Continuous Variables -  box plots, bar plots,

# %%
# Is there any relationship between sale_price and rating, 
# are customers rate products lower if the product is expensive?

sns.scatterplot(x = 'rating', y = 'sale_price', data = df)

# Correlation Coefficient
print(df['sale_price'].corr(df['rating']))

# So, there is no relationship between rating that customer provide and the price that product has,
# which means that customers don't rate the products by their price(cheap or expensive)
# Out:
# -0.08002610742307946

# %%
# Visualize how each numeric variable is correlated with each other

sns.pairplot(df)

# %%
# Find the categories with the highest average sale_price
sns.barplot(x = 'category', y = 'sale_price', data = df)
plt.xticks(rotation = 90)
plt.show()

# We can see that, category 'Baby Care' has the highest average price per product

# %%
# Find the market price for the top 5 most popular brands

brands_of_interest = df['brand'].value_counts().head(5)
df_filtered = df[df['brand'].isin(brands_of_interest.index)]

plt.figure(figsize=(10, 8))
sns.boxplot(x = 'brand', y = 'market_price', data = df_filtered, hue = 'brand')
# Out:
# <Axes: xlabel='brand', ylabel='market_price'>

# %%
# Find the average market price for the top 5 most popular brands

sns.barplot(x = 'brand', y = 'market_price', data = df_filtered)
# Out:
# <Axes: xlabel='brand', ylabel='market_price'>

# %% [markdown]
# # Finding Outliers

# %%
df.head()
# Out:
#                                              product                category  \
# 0             Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1                              Water Bottle - Orange  Kitchen, Garden & Pets
# 2                     Brass Angle Deep - Plain, No.2    Cleaning & Household
# 3  Cereal Flip Lid Container/Storage Jar - Assort...    Cleaning & Household
# 4                 Creme Soft Soap - For Hands & Body        Beauty & Hygiene
#
#             sub_category              brand  sale_price  market_price  \
# 0              Hair Care  Sri Sri Ayurveda        220.0         220.0
# 1  Storage & Accessories         Mastercook       180.0         180.0
# 2            Pooja Needs                Trm       119.0         250.0
# 3   Bins & Bathroom Ware             Nakoda       149.0         176.0
# 4       Bath & Hand Wash              Nivea       162.0         162.0
#
#                        type  rating  \
# 0          Hair Oil & Serum     4.1
# ...

# %%
sns.boxplot(df['sale_price'], orient = 'h')
# Here in sale_price we had a lot of outliers
# Out:
# <Axes: >

# %%
# Finding sale_price outliers

iqr = np.quantile(df['sale_price'], 0.75) - np.quantile(df['sale_price'], 0.25)

lower_th = np.quantile(df['sale_price'], 0.25) - (1.5 * iqr)
upper_th = np.quantile(df['sale_price'], 0.75) + (1.5 * iqr)

outliers = df[(df['sale_price'] < lower_th) | (df['sale_price'] > upper_th)]
outliers
# So, we have 1447 outliers in sale_price column
# Out:
#                                                  product  \
# 8      Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 25     Insulated Hot Fresh Casserole For Roti/Chapati...
# 47                                 Colour Catcher Sheets
# 51                                           Peach Syrup
# 91       Hard Anodised Ezee-Pour Saucepan With Lid - L88
# ...                                                  ...
# 27470                                            Nutella
# 27474                        Green Tea Bags - Detox Pack
# 27498            Juicer - Fruit & Vegetable, Light Green
# 27538  Quista Pro Advanced Whey Protein Formula forti...
# 27542                    Embellish Skin Lightening Serum
#
#                      category            sub_category            brand  \
# 8            Beauty & Hygiene               Hair Care       StBotanica
# 25     Kitchen, Garden & Pets       Flask & Casserole            Cello
# ...

# %%
# What is the mean and median sale_price in outliers?

outliers['sale_price'].mean() #1208.5134277816173
outliers['sale_price'].median() #940.0
# Out:
# 940.0

# %%
# Delete the outliers

df = df.drop(outliers.index)
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
sns.boxplot(df['sale_price'])
# Now, our boxplot looks much more better
# We can still see some outliers, but it's because column sale_price isn't normally distributed
# Out:
# <Axes: >

# %%
df['sale_price'].hist()
# It's not normally distributes, that's why we have some outliers left
# Out:
# <Axes: >
